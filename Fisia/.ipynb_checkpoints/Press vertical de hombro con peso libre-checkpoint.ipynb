# %% [markdown]
# ### "Press vertical de hombro con peso libre" (Ambos brazos)
#
# Segmentación de las repeticiones ejecutadas correctamente de este ejercicio.

# %%
from src.mongodb import *
from src.utils import *
from src.angle_calculations import *
from src.time_series_segmentation import *

# Define professional and exercise
professional_id = 112
exercise_name = "Press vertical de hombro con peso libre"

# Define keypoints to calculate reps
first_right_keypoint, second_right_keypoint, thrid_right_keypoint = 'right_shoulder', 'right_elbow','right_wrist'
first_left_keypoint, second_left_keypoint, thrid_left_keypoint = 'left_shoulder', 'left_elbow', 'left_wrist'

# Ángulos elevación brazo derecho
right_arm_angle = {'first_keypoint':first_right_keypoint, 
                  'second_keypoint':second_right_keypoint, 
                  'thrid_keypoint':thrid_right_keypoint}

left_arm_angle = {'first_keypoint':first_left_keypoint, 
                  'second_keypoint':second_left_keypoint, 
                  'thrid_keypoint':thrid_left_keypoint}



# Get documents
documents = fetch_correct_exercises(exercise_name, professional_id, db_uri='mongodb://root:root@192.168.219.38:27017/?authMechanism=DEFAULT',
                            db_name='fisia', collection_name='videos', correct_label=1)

# %% [markdown]
# #### Extraer las anotaciones y los keypoints de cada uno de los videos

# %%
n_videos = len(documents)
print("Número de vídeos anotados del ejercicio: " + str(n_videos))
video1 = documents[0]
video2 = documents[1]

video = video1

# Extraemos las características de los videos
annotations_data = extract_annotations(video)
start = annotations_data[0]['start'] - 1.5
end = annotations_data[0]['end'] + 1
reps = annotations_data[0]['reps']
label = annotations_data[0]['correct_label_range']

print("start: ", start)
print("end: ", end)
print("reps: ", reps)
print("label: ", label)

# Extraemos las anotaciones de cada video
all_frames_keypoints = extract_keypoints(video)
# print(all_frames_keypoints)
# Out:
# Número de vídeos anotados del ejercicio: 2
# http://api.fisia.ai/upload/multimedias/video-6643c52e3ec6a321270614.webm
# start:  4.5
# end:  26
# reps:  7
# label:  5

# %% [markdown]
# ### Recortar el video para su anotación

# %%
trimmed_keypoint_frames = trim_keypoint_frames(all_frames_keypoints, start, end, fps=25)

# Display or process the trimmed frames
print(f"Number of frames before trimming: {len(all_frames_keypoints)}")
print(f"Number of frames after trimming: {len(trimmed_keypoint_frames)}")
# Out:
# Number of frames before trimming: 511
# Number of frames after trimming: 399

# %% [markdown]
# ### Define Skeleton Connections and calculate movement angles

# %%
skeleton_connections = define_skeleton_connections()

# %%
right_arm_angles = calculate_movement_angles(trimmed_keypoint_frames, 
                                   right_arm_angle['first_keypoint'], 
                                   right_arm_angle['second_keypoint'], 
                                   right_arm_angle['thrid_keypoint'])

left_arm_angles = calculate_movement_angles(trimmed_keypoint_frames, 
                                   left_arm_angle['first_keypoint'], 
                                   left_arm_angle['second_keypoint'], 
                                   left_arm_angle['thrid_keypoint'])

# %% [markdown]
# #### Plot Time Series in 30FPS

# %%
time_series_angles(right_arm_angles, 'press hombro (Derecho)')
time_series_angles(left_arm_angles, 'press hombro (Izquierdo)')

# %% [markdown]
# #### Remove Nan Values

# %%
right_angles_clean = clean_time_series(right_arm_angles)
time_series_angles(right_angles_clean, 'press hombro (Derecho)')
left_angles_clean = clean_time_series(left_arm_angles)
time_series_angles(left_angles_clean, 'press hombro (Izquierdo)')

# %% [markdown]
# ####  Remove noise using the Savitzky-Golay filter

# %%
right_angles_smooth = time_series_smooth(right_angles_clean)
time_series_angles(right_angles_smooth, 'press hombro (Derecho)')
left_angles_smooth = time_series_smooth(left_angles_clean)
time_series_angles(left_angles_smooth, 'press hombro (Izquierdo)')

# %% [markdown]
# #### Normalización Min-Max

# %%
right_norm_angles = normalize_time_series(right_angles_smooth)
time_series_angles(right_norm_angles, 'Press hombro (Derecho)')
left_norm_angles = normalize_time_series(left_angles_smooth)
time_series_angles(left_norm_angles, 'Press hombro (Derecho)')

# %% [markdown]
# ### Búsqueda de repeticiones mediante procesamiento de señales

# %%
# Detección de picos y valles en la señal
right_peaks, right_valles = find_peaks_valleys(right_norm_angles, 0.6, 0.6, 25, 25, 0.4, 0.4)
left_peaks, left_valles = find_peaks_valleys(left_norm_angles, 0.6, 0.6, 25, 25, 0.4, 0.4)

# %% [markdown]
# #### Segmentación brazo derecho

# %%
right_segments = segment_series(right_angles_clean, right_peaks, right_valles, reps)
plot_generated_segments(right_segments)
# Out:
# 51

# %% [markdown]
# #### Segmentación brazo izquierdo

# %%
left_segments = segment_series(left_angles_clean, left_peaks, left_valles, reps)
plot_generated_segments(left_segments)
# Out:
# 49

# %% [markdown]
# ### Evaluar las repeticiones

# %%
right_stats = calculate_statistics_variables(right_segments)
left_stats = calculate_statistics_variables(left_segments)


# for i, stat in enumerate(stats):
#     print(f"Repetición {i+1}: "
#           f"Min={stat['min']:.2f}, "
#           f"Max={stat['max']:.2f}, "
#           f"Mediana={stat['median']:.2f}, "
#           f"Duración={stat['duration']} frames, "
#           f"Desviación Estándar={stat['standardDeviation']:.2f}, "
#           f"Media={stat['mean']:.2f}, "
#           f"Rango={stat['range']:.2f}, "
#           f"Varianza={stat['variance']:.2f}, "
#           f"CoV={stat['CoV']:.2f}, "
#           f"Asimetría={stat['skewness']:.2f}, "
#           f"Curtosis={stat['kurtosis']:.2f}, "
#           f"IQR={stat['IQR']:.2f}, "
#           f"Desplazamiento Total={stat['TotalDisplacement']:.2f}, "
#           f"Tasa de Cruce por Cero={stat['ZeroCrossingRate']}, "
#           f"Entropía={stat['Entropy']:.2f}, "
#           f"Suavidad={stat['Smoothness']:.2f}, "
#           f"Simetría={stat['Symmetry']:.2f}")

# %% [markdown]
# ##### Calculamos las medias y las desviaciones de las repeticiones correctas para poder definir los rangos de movimiento aproximados

# %%
def calcular_medias_desviaciones(stats):
    # Calcula la media y la desviación estándar para cada variable estadística de todas las repeticiones
    medias = {}
    desviaciones = {}
    for key in stats[0].keys():
        valores = [stat[key] for stat in stats]
        medias[key] = np.mean(valores)
        desviaciones[key] = np.std(valores)
    return medias, desviaciones

right_medias, right_desviaciones = calcular_medias_desviaciones(right_stats)
left_medias, left_desviaciones = calcular_medias_desviaciones(left_stats)

# %%
def calculate_range_medias_desviaciones(medias, desviaciones):
    rango_minimo_min = medias['min'] - desviaciones['min']
    rango_minimo_max = medias['min'] + desviaciones['min']
    print("Rango mínimo entre: " + str(rango_minimo_min) + " y "+ str(rango_minimo_max))
    
    rango_maximo_min = medias['max'] - desviaciones['max']
    rango_maximo_max = medias['max'] + desviaciones['max']
    print("Rango máximo entre: " + str(rango_maximo_min) + " y "+ str(rango_maximo_max))
    
    duracion_minima = medias['duration'] - desviaciones['duration']
    duracion_maxima = medias['duration'] + desviaciones['duration']
    print("Duración entre: " + str(duracion_minima) + " y "+ str(duracion_maxima))

calculate_range_medias_desviaciones(right_medias, right_desviaciones)
calculate_range_medias_desviaciones(left_medias, left_desviaciones)
# Out:
# Rango mínimo entre: 59.47363777724581 y 64.6739858521793
# Rango máximo entre: 166.1097630570328 y 176.53341673266618
# Duración entre: 33.8829728043953 y 67.83131290989041
# Rango mínimo entre: 67.16611554815594 y 80.41437600949118
# Rango máximo entre: 166.45874468573862 y 175.48371235475048
# Duración entre: 33.8829728043953 y 67.83131290989041

# %% [markdown]
# #### Esta función debería de ser fija calculada con el movimiento correcto estandar. Por lo tanto podemos anotar los rangos de movimiento

# %%
rango_minimo_min = 55
rango_minimo_max = 95
rango_maximo_min = 155
rango_maximo_max = 180
duracion_minima = 33.88
duracion_maxima = 67.83

# %%
def evaluar_repetición_dinámica(segment, rango_minimo_min, rango_minimo_max, rango_maximo_min, rango_maximo_max, duracion_minima, duracion_maxima):
    mensajes = []
    repetición_correcta = True

    duration = len(segment)
    if duration < duracion_minima:
        mensajes.append("Movimiento demasiado rápido, intenta hacerlo más lento.")
    elif duration > duracion_maxima:
        mensajes.append("Movimiento demasiado lento, intenta hacerlo más rápido.")

    min_angle = min(segment)
    max_angle = max(segment)

    if min_angle < rango_minimo_min:
        mensajes.append("Estás bajando demasiado.")
        repetición_correcta = False
    elif min_angle > rango_minimo_max:
        mensajes.append("Necesitas bajar más en el movimiento.")
        repetición_correcta = False

    if max_angle < rango_maximo_min:
        mensajes.append("Necesitas subir más, completa el movimiento.")
        repetición_correcta = False
    elif max_angle > rango_maximo_max:
        mensajes.append("No subas tanto, podrías hacerte daño.")
        repetición_correcta = False

    return repetición_correcta, mensajes

# %% [markdown]
# ##### Evaluación Brazo derecho

# %%
for i, right_segment in enumerate(right_segments):
    resultado = evaluar_repetición_dinámica(right_segment, rango_minimo_min, rango_minimo_max, rango_maximo_min, rango_maximo_max, duracion_minima, duracion_maxima)
    print(f"Resultado de la repetición {str(i+1)}: {resultado}")
# Out:
# Resultado de la repetición 1: (True, ['Movimiento demasiado lento, intenta hacerlo más rápido.'])
# Resultado de la repetición 2: (True, [])
# Resultado de la repetición 3: (True, [])
# Resultado de la repetición 4: (True, [])
# Resultado de la repetición 5: (True, [])
# Resultado de la repetición 6: (True, [])
# Resultado de la repetición 7: (True, ['Movimiento demasiado rápido, intenta hacerlo más lento.'])

# %% [markdown]
# ##### Evaluación Brazo izquierdo

# %%
for i, left_segment in enumerate(left_segments):
    resultado = evaluar_repetición_dinámica(left_segment, rango_minimo_min, rango_minimo_max, rango_maximo_min, rango_maximo_max, duracion_minima, duracion_maxima)
    print(f"Resultado de la repetición {str(i+1)}: {resultado}")
# Out:
# Resultado de la repetición 1: (True, ['Movimiento demasiado lento, intenta hacerlo más rápido.'])
# Resultado de la repetición 2: (True, [])
# Resultado de la repetición 3: (True, [])
# Resultado de la repetición 4: (True, [])
# Resultado de la repetición 5: (True, [])
# Resultado de la repetición 6: (True, [])
# Resultado de la repetición 7: (True, ['Movimiento demasiado rápido, intenta hacerlo más lento.'])
